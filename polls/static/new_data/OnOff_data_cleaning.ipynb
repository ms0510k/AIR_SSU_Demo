# %%
import pandas as pd

# %%
#읽을 파일 경로
file_path = r'C:\Users\sw\Desktop\DataGenerator_Device\GeneratedData\Generated_Data_0902_robotcleaner_200_debug.txt'

'''
f = open(file_path, 'r')
s = f.read()
print(s)
f.close()
'''

df = pd.read_csv(file_path, sep=' ',header=None, squeeze=True)
print(df)
# Out:
#             0      1  2           3             4              5            6  \
# 0           0  18000  1         NaN           NaN            NaN          NaN
# 1           1  18001  1  Chopsticks           NaN            NaN          NaN
# 2           2  18002  1       Basin           NaN            NaN          NaN
# 3           3  18003  1       Basin           NaN            NaN          NaN
# 4           4  18004  1  Chopsticks           NaN            NaN          NaN
# 5           5  18005  1  Chopsticks         Spoon            NaN          NaN
# 6           6  18006  1       Table   TableChair1     Chopsticks        Spoon
# 7           7  18007  1       Table   TableChair1     Chopsticks        Spoon
# 8           8  18008  1        Sofa  Refrigerator          Table  TableChair1
# 9           9  18009  1        Sofa     Bookshelf  RemoteControl          NaN
# 10         10  18010  1          TV          Sofa   MassageChair          NaN
# ...

# %%
df2 = df.drop([0,2,3,4,5,6,7,8], axis=1)

print(df2)
# Out:
#              1
# 0        18000
# 1        18001
# 2        18002
# 3        18003
# 4        18004
# 5        18005
# 6        18006
# 7        18007
# 8        18008
# 9        18009
# 10       18010
# 11       18011
# 12       18012
# 13       18013
# 14       18014
# 15       18015
# 16       18016
# 17       18017
# 18       18018
# 19       18019
# 20       18020
# 21       18021
# 22       18022
# 23       18023
# 24       18024
# 25       18025
# 26       18026
# 27       18027
# 28       18028
# 29       18029
# ...        ...
# 2990425  66270
# 2990426  66271
# 2990427  66272
# 2990428  66273
# 2990429  66274
# 2990430  66275
# 2990431  66276
# 2990432  66277
# 2990433  66278
# 2990434  66279
# 2990435  66280
# 2990436  66281
# 2990437  66282
# 2990438  66283
# 2990439  66284
# 2990440  66285
# 2990441  66286
# 2990442  66287
# 2990443  66288
# 2990444  66289
# 2990445  66290
# 2990446  66291
# 2990447  66292
# 2990448  66293
# 2990449  66294
# 2990450  66295
# ...

# %%
df3 = df2.loc[(df[7].str.contains('On')), :]

#저장할 경로
df3.to_csv(r"C:\Users\sw\Desktop\DataGenerator_Device\GeneratedData\Generated_Data_0902_robotcleaner_200_debug.csv",sep=' ',index=False)

print(df3)
# Out:
#              1
# 19811    37800
# 19812    37801
# 19813    37802
# 19814    37803
# 19815    37804
# 19816    37805
# 19817    37806
# 19818    37807
# 19819    37808
# 19820    37809
# 19821    37810
# 19822    37811
# 19823    37812
# 19824    37813
# 19825    37814
# 19826    37815
# 19827    37816
# 19828    37817
# 19829    37818
# 19830    37819
# 19831    37820
# 19832    37821
# 19833    37822
# 19834    37823
# 19835    37824
# 19836    37825
# 19837    37826
# 19838    37827
# 19839    37828
# 19840    37829
# ...        ...
# 2978125  53970
# 2978126  53971
# 2978127  53972
# 2978128  53973
# 2978129  53974
# 2978130  53975
# 2978131  53976
# 2978132  53977
# 2978133  53978
# 2978134  53979
# 2978135  53980
# 2978136  53981
# 2978137  53982
# 2978138  53983
# 2978139  53984
# 2978140  53985
# 2978141  53986
# 2978142  53987
# 2978143  53988
# 2978144  53989
# 2978145  53990
# 2978146  53991
# 2978147  53992
# 2978148  53993
# 2978149  53994
# 2978150  53995
# ...

# %%
data1=[1]
data2=[2]
data3=[3]
data4=[4]

# %%
for i in range(4):
    print(data[i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e484c6474e15> in <module>()
#       1 for i in range(4):
# ----> 2     print(data[i])
#
# NameError: name 'data' is not defined

# %%
import re
import os
import sys
import csv
import pandas as pd
import numpy as np
import datetime
from datetime import timedelta
from time import sleep
from sklearn.mixture import GaussianMixture


file_name = r"C:\Users\User\Desktop\1010\DjangoTest\polls\static\Generated_data_random\1.csv"
                
df = pd.read_csv(file_name, sep='\t', header=None, squeeze=True, encoding='cp949')

new_df = df[[0,4]].copy()

print(new_df)
# Out:
#          0              4
# 0    08:00  5.740447e-139
# 1    08:01  1.072122e-138
# 2    08:02  2.001110e-138
# 3    08:03  3.732729e-138
# 4    08:04  6.958417e-138
# 5    08:05  1.296352e-137
# 6    08:06  2.413594e-137
# 7    08:07  4.490906e-137
# 8    08:08  8.350880e-137
# 9    08:09  1.551884e-136
# 10   08:10  2.882136e-136
# 11   08:11  5.349319e-136
# 12   08:12  9.922271e-136
# 13   08:13  1.839299e-135
# 14   08:14  3.407391e-135
# 15   08:15  6.308414e-135
# 16   08:16  1.167205e-134
# 17   08:17  2.158253e-134
# 18   08:18  3.988286e-134
# 19   08:19  7.365443e-134
# 20   08:20  1.359377e-133
# 21   08:21  2.507319e-133
# 22   08:22  4.621765e-133
# 23   08:23  8.514019e-133
# 24   08:24  1.567437e-132
# 25   08:25  2.883858e-132
# 26   08:26  5.302569e-132
# 27   08:27  9.743779e-132
# 28   08:28  1.789357e-131
# 29   08:29  3.283940e-131
# ..     ...            ...
# 210  11:30   5.956288e-88
# 211  11:31   9.756024e-88
# 212  11:32   1.596977e-87
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
t = np.arange(0, 240)

file_name = r"C:\Users\User\Desktop\1010\DjangoTest\polls\static\Generated_data_random\1.csv"
                
df = pd.read_csv(file_name, sep='\t', header=None, squeeze=True, encoding='cp949')
#t = df.pop(0)
s = df.pop(4)
#print(s)

fig, ax = plt.subplots()
ax.plot(t, s)

ax.set(xlabel='time (s)', ylabel='voltage (mV)',
       title='About as simple as it gets, folks')
ax.grid()

plt.show()

# %%
dir_name = ".\park\summer\weekend\"

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
t = np.arange(0, 240)

file_name = r".\park\summer\weekend\aircleaner\1.csv"
           

df = pd.read_csv(file_name, sep='\t', header=None, squeeze=True, encoding='cp949')
#print(df)
#t = df.pop(0)
s = df.pop(5)
#print(s)

fig, ax = plt.subplots()
ax.plot( s)

ax.set(xlabel='time (s)', ylabel='voltage (mV)',
       title='About as simple as it gets, folks')
ax.grid()

plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
t = np.arange(0, 240)

file_name = r".\park\summer\weekend\airconditioner\1.csv"
                
df = pd.read_csv(file_name, sep='\t', header=None, squeeze=True, encoding='cp949')
#t = df.pop(0)
s = df.pop(5)
#print(s)

fig, ax = plt.subplots()
ax.plot( s)

ax.set(xlabel='time (s)', ylabel='voltage (mV)',
       title='About as simple as it gets, folks')
ax.grid()

plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
t = np.arange(0, 240)

file_name = r".\park\summer\weekend\bulb\1.csv"
                
df = pd.read_csv(file_name, sep='\t', header=None, squeeze=True, encoding='cp949')
t = df.pop(1)
s = df.pop(5)
#print(s)

fig, ax = plt.subplots()
ax.plot(t, s)

ax.set(xlabel='time (s)', ylabel='voltage (mV)',
       title='About as simple as it gets, folks')
ax.grid()

plt.show()

# %%
header_list = ["Time", "Min", "User", "Device", "N_Com", "Prob", "On", "Season", "Week", "Weather"]

df = pd.read_csv(file_name, sep='\t', header=None, names=header_list, encoding='cp949')
#print(df)

# @jaeseung : need to get on time
for index, row in df.iterrows():
    if row["On"] == "On":
        print(row["Min"])
# Out:
# 660.0
# 661.0
# 662.0
# 663.0
# 664.0
# 665.0
# 666.0
# 667.0
# 668.0
# 669.0
# 670.0
# 671.0
# 672.0
# 673.0
# 674.0
# 675.0
# 676.0
# 677.0
# 678.0
# 679.0
# 680.0
# 681.0
# 682.0
# 683.0
# 684.0
# 685.0
# 686.0
# 687.0
# 688.0
# 689.0
# 690.0
# 691.0
# 692.0
# 693.0
# 694.0
# 695.0
# 696.0
# 697.0
# 698.0
# 699.0
# 700.0
# 701.0
# 702.0
# 703.0
# 704.0
# 705.0
# 706.0
# 707.0
# 708.0
# 709.0
# 710.0
# 711.0
# 712.0
# 713.0
# 714.0
# 715.0
# 716.0
# 717.0
# 718.0
# 719.0
# 720.0
# 721.0
# 722.0
# 723.0
# 724.0
# 725.0
# 726.0
# 727.0
# 728.0
# 729.0
# 730.0
# 731.0
# 732.0
# 733.0
# 734.0
# 735.0
# 736.0
# 737.0
# 738.0
# 739.0
# 740.0
# 950.0
# 951.0
# 952.0
# 953.0
# 954.0
# 955.0
# 956.0
# 957.0
# 958.0
# 959.0
# 960.0
# 961.0
# 962.0
# 963.0
# 964.0
# 965.0
# 966.0
# 967.0
# 968.0
# 969.0
# 970.0
# 971.0
# 972.0
# 973.0
# 974.0
# 975.0
# 976.0
# 977.0
# 978.0
# 979.0
# 980.0
# 981.0
# 982.0
# 983.0
# 984.0
# 985.0
# 986.0
# 987.0
# 988.0
# 989.0
# 990.0
# 991.0
# 992.0
# 993.0
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Data for plotting
t = np.arange(0, 240)

file_name = r".\park\summer\weekend\robotcleaner\1.csv"
                
df = pd.read_csv(file_name, sep='\t', header=None, squeeze=True, encoding='cp949')
t = df.pop(1)
s = df.pop(5)
#print(s)

fig, ax = plt.subplots()
ax.plot(t, s)

ax.set(xlabel='time (s)', ylabel='voltage (mV)',
       title='About as simple as it gets, folks')
ax.grid()

plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
t = np.arange(0, 240)

file_name = r".\park\summer\weekend\tv\1.csv"
                
df = pd.read_csv(file_name, sep='\t', header=None, squeeze=True, encoding='cp949')
t = df.pop(1)
s = df.pop(5)
#print(s)

fig, ax = plt.subplots()
ax.plot(t, s)

ax.set(xlabel='time (s)', ylabel='voltage (mV)',
       title='About as simple as it gets, folks')
ax.grid()

plt.show()

# %%
#print(df)

# %%
df = pd.read_csv(file_name, sep='\t', header=None, squeeze=True, encoding='cp949')
print(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-e7f84ff263f0> in <module>()
# ----> 1 df = pd.read_csv(file_name, sep='\t', header=None, squeeze=True, encoding='cp949')
#       2 print(df)
#
# ...

# %%
print(df)
# Out:
#          0       1     2   3  4    6       7        8     9
# 0    08:00   480.0  park  TV  2  Off  summer  weekend  rain
# 1    08:01   481.0  park  TV  2  Off  summer  weekend  rain
# 2    08:02   482.0  park  TV  2  Off  summer  weekend  rain
# 3    08:03   483.0  park  TV  2  Off  summer  weekend  rain
# 4    08:04   484.0  park  TV  2  Off  summer  weekend  rain
# 5    08:05   485.0  park  TV  2  Off  summer  weekend  rain
# 6    08:06   486.0  park  TV  2  Off  summer  weekend  rain
# 7    08:07   487.0  park  TV  2  Off  summer  weekend  rain
# 8    08:08   488.0  park  TV  2  Off  summer  weekend  rain
# 9    08:09   489.0  park  TV  2  Off  summer  weekend  rain
# 10   08:10   490.0  park  TV  2  Off  summer  weekend  rain
# 11   08:11   491.0  park  TV  2  Off  summer  weekend  rain
# 12   08:12   492.0  park  TV  2  Off  summer  weekend  rain
# 13   08:13   493.0  park  TV  2  Off  summer  weekend  rain
# 14   08:14   494.0  park  TV  2  Off  summer  weekend  rain
# ...

# %%
tempSpringMin = 15
tempSpringMax = 25

tempSummerMin = 25
tempSummerMax = 35

tempFallMin = 15
tempFallMax = 25

tempWinterMin = -10
tempWinterMax = 5


    dustSpringMin = 35
    dustSpringMax = 70

    dustSummerMin = 25
    dustSummerMax = 45

    dustFallMin = 25
    dustFallMax = 45

    dustWinterMin = 35
    dustWinterMax = 70

# %%
weather = "spring"
temp_thres = 20
dust_thres = 40

if weather == "spring":
    temp_min = 15
    temp_max = 25
    dust_min = 35
    dust_max = 70
elif weather == "summer":
    temp_min = 25
    temp_max = 35
    dust_min = 25
    dust_max = 45
elif weather == "fall":
    temp_min = 15
    temp_max = 25
    dust_min = 25
    dust_max = 45
elif weather == "winter":
    temp_min = -10
    temp_max = 5
    dust_min = 35
    dust_max = 70
    
temp_list = []
temp_list.append(temp_min)
temp_list.append(temp_max)
temp_list.append(temp_thres)

temp_list.append(dust_min)
temp_list.append(dust_max)
temp_list.append(dust_thres)

print(temp_list)
header_list= ["Temp_Min", "Temp_Max", "Temp_Thres", "Dust_Min", "Dust_Max", "Dust_Thres"]

temp_df = pd.DataFrame([temp_list], columns=header_list)
print(temp_df)
temp_df.to_csv()
df3.to_csv(r"C:\Users\sw\Desktop\DataGenerator_Device\GeneratedData\Generated_Data_0902_robotcleaner_200_debug.csv",sep=' ',index=False)
# Out:
# [15, 25, 20, 35, 70, 40]
#    Temp_Min  Temp_Max  Temp_Thres  Dust_Min  Dust_Max  Dust_Thres
# 0        15        25          20        35        70          40

# %%
dust_x = np.linspace(0, 10, 10)
dust_y = np.linspace(0, 10, 10)
dust_y2 = np.linspace(0, 10, 10)
dust_y[dust_x <= 5] = 0
dust_y[dust_x > 5] = 1
dust_y2[dust_x <= 5] = 0
dust_y2[dust_x > 5] = 1

dust_list = np.c_[dust_x, dust_y]
print(dust_list)
dust_list = np.c_[dust_list, dust_y2]
dust_list = dust_list.tolist()
print(dust_list)
# Out:
# [[  0.           0.        ]
#  [  1.11111111   0.        ]
#  [  2.22222222   0.        ]
#  [  3.33333333   0.        ]
#  [  4.44444444   0.        ]
#  [  5.55555556   1.        ]
#  [  6.66666667   1.        ]
#  [  7.77777778   1.        ]
#  [  8.88888889   1.        ]
#  [ 10.           1.        ]]
# [[0.0, 0.0, 0.0], [1.1111111111111112, 0.0, 0.0], [2.2222222222222223, 0.0, 0.0], [3.3333333333333335, 0.0, 0.0], [4.444444444444445, 0.0, 0.0], [5.555555555555555, 1.0, 1.0], [6.666666666666667, 1.0, 1.0], [7.777777777777779, 1.0, 1.0], [8.88888888888889, 1.0, 1.0], [10.0, 1.0, 1.0]]
