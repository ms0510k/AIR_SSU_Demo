# %%
import re
import os
import sys
import csv
import pandas as pd
import numpy as np
import datetime
from datetime import timedelta

# %%
root_dir = "."

user_dir = root_dir + "park"

aircon_dir = user_dir + 'airconditioner'

aircleaner_dir = user_dir + 'aircleaner'

bulb_dir = user_dir + 'bulb'

robot_dir = user_dir + 'robotcleaner'

tv_dir = user_dir + 'tv'

user_list = ['park', 'kim', 'choi']

device_list = ['airconditioner', 'aircleaner', 'bulb', 'robotcleaner', 'tv']

season_list = ['spring', 'summer', 'fall', 'winter']

week_list = ['weekdays', 'weekend']

choose_list = []


#* len(device_list) * len(season_list) * len(week_list)) :

for i in range(len(user_list)):
    for j in range(len(device_list)):
        for k in range(len(season_list)):
            for n in range(len(week_list)):
                choose_list.append(
                    root_dir + "/" + user_list[i] + "/" + device_list[j] + "/" 
                    + season_list[k] + "/" + week_list[n])

for i in choose_list:
    print(i)
# Out:
# ./park/airconditioner/spring/weekdays
# ./park/airconditioner/spring/weekend
# ./park/airconditioner/summer/weekdays
# ./park/airconditioner/summer/weekend
# ./park/airconditioner/fall/weekdays
# ./park/airconditioner/fall/weekend
# ./park/airconditioner/winter/weekdays
# ./park/airconditioner/winter/weekend
# ./park/aircleaner/spring/weekdays
# ./park/aircleaner/spring/weekend
# ./park/aircleaner/summer/weekdays
# ./park/aircleaner/summer/weekend
# ./park/aircleaner/fall/weekdays
# ./park/aircleaner/fall/weekend
# ./park/aircleaner/winter/weekdays
# ./park/aircleaner/winter/weekend
# ./park/bulb/spring/weekdays
# ./park/bulb/spring/weekend
# ./park/bulb/summer/weekdays
# ./park/bulb/summer/weekend
# ./park/bulb/fall/weekdays
# ./park/bulb/fall/weekend
# ./park/bulb/winter/weekdays
# ./park/bulb/winter/weekend
# ./park/robotcleaner/spring/weekdays
# ./park/robotcleaner/spring/weekend
# ./park/robotcleaner/summer/weekdays
# ./park/robotcleaner/summer/weekend
# ./park/robotcleaner/fall/weekdays
# ./park/robotcleaner/fall/weekend
# ./park/robotcleaner/winter/weekdays
# ./park/robotcleaner/winter/weekend
# ./park/tv/spring/weekdays
# ./park/tv/spring/weekend
# ./park/tv/summer/weekdays
# ./park/tv/summer/weekend
# ./park/tv/fall/weekdays
# ./park/tv/fall/weekend
# ./park/tv/winter/weekdays
# ./park/tv/winter/weekend
# ./kim/airconditioner/spring/weekdays
# ./kim/airconditioner/spring/weekend
# ./kim/airconditioner/summer/weekdays
# ./kim/airconditioner/summer/weekend
# ./kim/airconditioner/fall/weekdays
# ./kim/airconditioner/fall/weekend
# ./kim/airconditioner/winter/weekdays
# ./kim/airconditioner/winter/weekend
# ./kim/aircleaner/spring/weekdays
# ./kim/aircleaner/spring/weekend
# ./kim/aircleaner/summer/weekdays
# ./kim/aircleaner/summer/weekend
# ./kim/aircleaner/fall/weekdays
# ./kim/aircleaner/fall/weekend
# ./kim/aircleaner/winter/weekdays
# ./kim/aircleaner/winter/weekend
# ./kim/bulb/spring/weekdays
# ./kim/bulb/spring/weekend
# ./kim/bulb/summer/weekdays
# ./kim/bulb/summer/weekend
# ./kim/bulb/fall/weekdays
# ./kim/bulb/fall/weekend
# ./kim/bulb/winter/weekdays
# ./kim/bulb/winter/weekend
# ./kim/robotcleaner/spring/weekdays
# ./kim/robotcleaner/spring/weekend
# ./kim/robotcleaner/summer/weekdays
# ./kim/robotcleaner/summer/weekend
# ./kim/robotcleaner/fall/weekdays
# ./kim/robotcleaner/fall/weekend
# ./kim/robotcleaner/winter/weekdays
# ./kim/robotcleaner/winter/weekend
# ./kim/tv/spring/weekdays
# ./kim/tv/spring/weekend
# ./kim/tv/summer/weekdays
# ./kim/tv/summer/weekend
# ./kim/tv/fall/weekdays
# ./kim/tv/fall/weekend
# ./kim/tv/winter/weekdays
# ./kim/tv/winter/weekend
# ./choi/airconditioner/spring/weekdays
# ./choi/airconditioner/spring/weekend
# ./choi/airconditioner/summer/weekdays
# ./choi/airconditioner/summer/weekend
# ./choi/airconditioner/fall/weekdays
# ./choi/airconditioner/fall/weekend
# ./choi/airconditioner/winter/weekdays
# ./choi/airconditioner/winter/weekend
# ./choi/aircleaner/spring/weekdays
# ./choi/aircleaner/spring/weekend
# ./choi/aircleaner/summer/weekdays
# ./choi/aircleaner/summer/weekend
# ./choi/aircleaner/fall/weekdays
# ./choi/aircleaner/fall/weekend
# ./choi/aircleaner/winter/weekdays
# ./choi/aircleaner/winter/weekend
# ./choi/bulb/spring/weekdays
# ./choi/bulb/spring/weekend
# ./choi/bulb/summer/weekdays
# ./choi/bulb/summer/weekend
# ./choi/bulb/fall/weekdays
# ./choi/bulb/fall/weekend
# ./choi/bulb/winter/weekdays
# ./choi/bulb/winter/weekend
# ./choi/robotcleaner/spring/weekdays
# ./choi/robotcleaner/spring/weekend
# ./choi/robotcleaner/summer/weekdays
# ./choi/robotcleaner/summer/weekend
# ./choi/robotcleaner/fall/weekdays
# ./choi/robotcleaner/fall/weekend
# ./choi/robotcleaner/winter/weekdays
# ./choi/robotcleaner/winter/weekend
# ./choi/tv/spring/weekdays
# ./choi/tv/spring/weekend
# ./choi/tv/summer/weekdays
# ./choi/tv/summer/weekend
# ./choi/tv/fall/weekdays
# ./choi/tv/fall/weekend
# ./choi/tv/winter/weekdays
# ./choi/tv/winter/weekend

# %%
for i in choose_list:
    if not os.path.exists(i):
        os.makedirs(i)

# %%
file_list = []

def search_dir(dirname, file_list):
    for (path, dir, files) in os.walk(dirname):
        for filename in files:
            ext = os.path.splitext(filename)[-1]
            if ext == '.csv':
                #print("%s/%s" % (path, filename))
                tmp = path + '/' + filename
                #print(tmp)
                file_list.append(tmp)
                
search_dir(choose_list[0], file_list)

print(choose_list[0])
print("list : \n")
for i in file_list:
    print(i)
# Out:
# ./park/airconditioner/spring/weekdays
# list :
#
# ./park/airconditioner/spring/weekdays/Generated_Data_example100_TV.csv

# %%
file_list2= [] 
for i in file_list:
    file_list2.append(os.path.abspath(i))
    
for i in file_list2:
    print(i)
# Out:
# C:\Users\User\Desktop\1010\DjangoTest\polls\static\data_test\park\airconditioner\spring\weekdays\Generated_Data_example100_TV.csv

# %%
df_list = []
count = 0


for i in file_list2:
    print(i)
    df_list.append(pd.read_csv(i, delimiter='\t', header=None, encoding='CP949'))

print(len(df_list))
    
for i in df_list:
    print(df_list[count])
    count += 1
# Out:
# C:\Users\User\Desktop\1010\DjangoTest\polls\static\data_test\park\airconditioner\spring\weekdays\Generated_Data_example100_TV.csv
# 1
#         0  1   2    3       4         5     6
# 0   24013  1  TV   On  Winter  Weekdays  Blur
# 1   24014  1  TV   On  Winter  Weekdays  Blur
# 2   24015  1  TV   On  Winter  Weekdays  Blur
# 3   24016  1  TV   On  Winter  Weekdays  Blur
# 4   24017  1  TV   On  Winter  Weekdays  Blur
# 5   24018  1  TV   On  Winter  Weekdays  Blur
# 6   24019  1  TV   On  Winter  Weekdays  Blur
# 7   24020  1  TV   On  Winter  Weekdays  Blur
# 8   24021  1  TV   On  Winter  Weekdays  Blur
# 9   24022  1  TV   On  Winter  Weekdays  Blur
# 10  24023  1  TV   On  Winter  Weekdays  Blur
# 11  24024  1  TV   On  Winter  Weekdays  Blur
# 12  24025  1  TV   On  Winter  Weekdays  Blur
# 13  24026  1  TV   On  Winter  Weekdays  Blur
# 14  24027  1  TV   On  Winter  Weekdays  Blur
# 15  24028  1  TV   On  Winter  Weekdays  Blur
# 16  24029  1  TV   On  Winter  Weekdays  Blur
# 17  24030  1  TV   On  Winter  Weekdays  Blur
# 18  24031  1  TV   On  Winter  Weekdays  Blur
# 19  24032  1  TV   On  Winter  Weekdays  Blur
# 20  24033  1  TV   On  Winter  Weekdays  Blur
# 21  24034  1  TV   On  Winter  Weekdays  Blur
# 22  24035  1  TV   On  Winter  Weekdays  Blur
# 23  24036  1  TV   On  Winter  Weekdays  Blur
# 24  24037  1  TV   On  Winter  Weekdays  Blur
# 25  24038  1  TV   On  Winter  Weekdays  Blur
# 26  24039  1  TV   On  Winter  Weekdays  Blur
# 27  24040  1  TV  Off  Winter  Weekdays  Blur
# 28  24041  1  TV  Off  Winter  Weekdays  Blur
# 29  24042  1  TV  Off  Winter  Weekdays  Blur
# ..    ... ..  ..  ...     ...       ...   ...
# 70  24083  1  TV   On  Winter  Weekdays  Blur
# 71  24084  1  TV   On  Winter  Weekdays  Blur
# 72  24085  1  TV   On  Winter  Weekdays  Blur
# 73  24086  1  TV   On  Winter  Weekdays  Blur
# 74  24087  1  TV   On  Winter  Weekdays  Blur
# 75  24088  1  TV   On  Winter  Weekdays  Blur
# 76  24089  1  TV   On  Winter  Weekdays  Blur
# 77  24090  1  TV   On  Winter  Weekdays  Blur
# 78  24091  1  TV   On  Winter  Weekdays  Blur
# 79  24092  1  TV   On  Winter  Weekdays  Blur
# 80  24093  1  TV   On  Winter  Weekdays  Blur
# 81  24094  1  TV   On  Winter  Weekdays  Blur
# 82  24095  1  TV   On  Winter  Weekdays  Blur
# 83  24096  1  TV   On  Winter  Weekdays  Blur
# 84  24097  1  TV   On  Winter  Weekdays  Blur
# 85  24098  1  TV   On  Winter  Weekdays  Blur
# 86  24099  1  TV   On  Winter  Weekdays  Blur
# 87  24100  1  TV   On  Winter  Weekdays  Blur
# 88  24101  1  TV   On  Winter  Weekdays  Blur
# 89  24102  1  TV   On  Winter  Weekdays  Blur
# 90  24103  1  TV   On  Winter  Weekdays  Blur
# 91  24104  1  TV   On  Winter  Weekdays  Blur
# 92  24105  1  TV   On  Winter  Weekdays  Blur
# 93  24106  1  TV   On  Winter  Weekdays  Blur
# 94  24107  1  TV   On  Winter  Weekdays  Blur
# 95  24108  1  TV   On  Winter  Weekdays  Blur
# 96  24109  1  TV   On  Winter  Weekdays  Blur
# 97  24110  1  TV   On  Winter  Weekdays  Blur
# 98  24111  1  TV   On  Winter  Weekdays  Blur
# 99  24112  1  TV   On  Winter  Weekdays  Blur
#
# [100 rows x 7 columns]

# %%
new = choose_list[0] + "/tmp"
for i in range(10):
    new2 = new+str(i) +".csv"
    print(new2)
    df_list[0].to_csv(new2, sep='\t', encoding='utf-8')
# Out:
# ./park/airconditioner/spring/weekdays/tmp0
# ./park/airconditioner/spring/weekdays/tmp1
# ./park/airconditioner/spring/weekdays/tmp2
# ./park/airconditioner/spring/weekdays/tmp3
# ./park/airconditioner/spring/weekdays/tmp4
# ./park/airconditioner/spring/weekdays/tmp5
# ./park/airconditioner/spring/weekdays/tmp6
# ./park/airconditioner/spring/weekdays/tmp7
# ./park/airconditioner/spring/weekdays/tmp8
# ./park/airconditioner/spring/weekdays/tmp9

# %%
_
